# %%
import pandas as pd
titanic_survival = pd.read_csv("titanic.csv")
age = titanic_survival["age"]
age_is_not_null = pd.notnull(age)
age_null_false = age[age_is_not_null]
print(age_null_false)
# Out:
# 0       42.0000
# 1       13.0000
# 2       16.0000
# 3       35.0000
# 4       16.0000
# 5       25.0000
# 6       30.0000
# 7       28.0000
# 8       20.0000
# 9       18.0000
# 10      30.0000
# 11      26.0000
# 12      40.0000
# 13       0.8333
# 14      18.0000
# 15      26.0000
# 16      30.0000
# 17      26.0000
# 18      20.0000
# 19      24.0000
# 20      25.0000
# 21      29.0000
# 22      35.0000
# 23       0.9167
# 24       2.0000
# 25      30.0000
# 26      25.0000
# 27      18.0000
# 28      19.0000
# 29      32.0000
#          ...
# 1269    31.0000
# 1270    57.0000
# 1271    45.0000
# 1272    51.0000
# 1273    50.0000
# 1274    27.0000
# 1275    50.0000
# 1276    18.0000
# 1277    21.0000
# 1278    31.0000
# 1279    47.0000
# 1280    21.0000
# 1284    51.0000
# 1287    28.5000
# 1288    21.0000
# 1289    31.0000
# 1290    21.0000
# 1291    27.0000
# 1293    36.0000
# 1295    26.0000
# 1296    62.0000
# 1297    27.0000
# 1298    15.0000
# 1299    36.0000
# ...

# %%
age_is_null = pd.isnull(age)
age_null_true = age[age_is_null]
print(age_null_true)
# Out:
# 97     NaN
# 118    NaN
# 139    NaN
# 140    NaN
# 141    NaN
# 150    NaN
# 156    NaN
# 182    NaN
# 190    NaN
# 195    NaN
# 196    NaN
# 215    NaN
# 230    NaN
# 232    NaN
# 243    NaN
# 270    NaN
# 278    NaN
# 288    NaN
# 313    NaN
# 314    NaN
# 328    NaN
# 330    NaN
# 343    NaN
# 373    NaN
# 379    NaN
# 387    NaN
# 391    NaN
# 393    NaN
# 394    NaN
# 395    NaN
#         ..
# 1152   NaN
# 1178   NaN
# 1185   NaN
# 1186   NaN
# 1187   NaN
# 1189   NaN
# 1190   NaN
# 1191   NaN
# 1192   NaN
# 1194   NaN
# 1195   NaN
# 1199   NaN
# 1201   NaN
# 1215   NaN
# 1222   NaN
# 1240   NaN
# 1244   NaN
# 1247   NaN
# 1251   NaN
# 1265   NaN
# 1281   NaN
# 1282   NaN
# 1283   NaN
# 1285   NaN
# 1286   NaN
# 1292   NaN
# 1294   NaN
# 1301   NaN
# 1302   NaN
# 1305   NaN
# Name: age, Length: 263, dtype: float64

# %%
#Use age_is_null to create a vector that only contains values from the "age" column that aren't NaN.
#Calculate the mean of the new vector, and assign the result to correct_mean_age.
age_null_false = age[age_is_not_null]
age_null_false.mean()
# Out:
# 29.8811345124283

# %%
passenger_classes = [1, 2, 3]
fares_by_class = {}
for this_class in passenger_classes:
    pclass_rows = titanic_survival[titanic_survival["pclass"] == this_class]
    pclass_fares = pclass_rows["fare"]
    fare_for_class = pclass_fares.mean()
    fares_by_class[this_class] = fare_for_class

# %%
pclass_rows
# Out:
#       pclass  survived                                             name  \
# 0          3         0                              Abbing, Mr. Anthony
# 1          3         0                    Abbott, Master. Eugene Joseph
# 2          3         0                      Abbott, Mr. Rossmore Edward
# 3          3         1                 Abbott, Mrs. Stanton (Rosa Hunt)
# 4          3         1                      Abelseth, Miss. Karen Marie
# 5          3         1                    Abelseth, Mr. Olaus Jorgensen
# 8          3         1         Abrahamsson, Mr. Abraham August Johannes
# 9          3         1        Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 10         3         0                   Adahl, Mr. Mauritz Nils Martin
# 11         3         0                                  Adams, Mr. John
# 12         3         0   Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 13         3         1                        Aks, Master. Philip Frank
# ...

# %%
titanic_survival.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
def number_null(column):
    # Extract the hundredth item
    counter_item = column.isnull().sum()
    
    return counter_item

column_null_count=titanic_survival.apply(number_null)
print(column_null_count)
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     563
# dtype: int64
